# %% [markdown]
# ## **메모**
# ---
#
# ```
# A사는 Electronics(전자제품) E-commerce 사업을 운영하고 있다.
# Data Analytics팀은 현재 수집된 데이터를 활요하여거래 history, 프로모션, 고객충성도 등의 다양한 데이터를
# 활용하여 현재 'A사의 E-commerce 사업이 잘 되고 있는지' 파악하려한다.
# ```
#
# ```
# [분석 주제 예시]
# (고객) 년도, 월 별 고객 증가률은?
# (고객) 고객 Sege별 수행해야 하는 마케팅은?
# (상품) 상품 카테 고리별 매출 및 수익 현황은?
# (상품) 매출 하락 또는 증가에 원인은?
# (프로모션/광고 효과 검증) 투자 및 프로모션에 따른 마케팅 효과는?
# (프로모션/광고 효과 검증) 효율적 마케팅은?
# ```

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# from google.colab import drive
# drive.mount('/content/drive')

# import os
# os.chdir('/content/drive/MyDrive')
# os.getcwd()

# %% [markdown]
# # 메인 데이터 사전 EDA

# %%
import pandas as pd

df = pd.read_csv('ConsumerElectronics.csv')
df.head()
# Out:
#              fsn_id           order_date  Year  Month      order_id  \
# 0  ACCCX3S58G7B5F6P  2015-10-17 15:11:54  2015     10  3.419301e+15
# 1  ACCCX3S58G7B5F6P  2015-10-19 10:07:22  2015     10  1.420831e+15
# 2  ACCCX3S5AHMF55FV  2015-10-20 15:45:56  2015     10  2.421913e+15
# 3  ACCCX3S5AHMF55FV  2015-10-14 12:05:15  2015     10  4.416592e+15
# 4  ACCCX3S5AHMF55FV  2015-10-17 21:25:03  2015     10  4.419525e+15
#
#    order_item_id   gmv  units deliverybdays deliverycdays  \
# 0   3.419301e+15  6400      1            \N            \N
# 1   1.420831e+15  6900      1            \N            \N
# 2   2.421913e+15  1990      1            \N            \N
# 3   4.416592e+15  1690      1            \N            \N
# 4   4.419525e+15  1618      1            \N            \N
#
#   s1_fact.order_payment_type  sla                 cust_id  \
# 0                        COD    5  -1.01299130778588E+018
# 1                        COD    7  -8.99032457905512E+018
# ...

# %%
print(df.shape)
# Out:
# (1648824, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1648824 entries, 0 to 1648823
# Data columns (total 20 columns):
#  #   Column                           Non-Null Count    Dtype
# ---  ------                           --------------    -----
#  0   fsn_id                           1648824 non-null  object
#  1   order_date                       1648824 non-null  object
#  2   Year                             1648824 non-null  int64
#  3   Month                            1648824 non-null  int64
#  4   order_id                         1648824 non-null  float64
#  5   order_item_id                    1648824 non-null  float64
#  6   gmv                              1648824 non-null  object
#  7   units                            1648824 non-null  int64
#  8   deliverybdays                    1648824 non-null  object
#  9   deliverycdays                    1648824 non-null  object
#  10  s1_fact.order_payment_type       1648824 non-null  object
# ...

# %%
df['deliverybdays'].unique()
# Out:
# array(['\\N', '5', '4', '12', '6', '7', '8', '3', '9', '10', '2', '16',
#        '14', '13', '20', '11', '1', '18', '32', '15', '238', '153', '74',
#        '128', '148', '145', '147', '135', '124', '94', '111', '101',
#        '105', '104', '98', '86', '106', '103', '99', '91', '96', '93',
#        '100', '102', '95', '97', '92', '88', '87', '114', '120', '115',
#        '132', '70', '83', '72', '0', '73', '76', '67', '75', '68', '65',
#        '84', '63', '82', '81', '79', '64', '69', '61', '59', '60', '78',
#        '66', '62', '71', '77', '80', '85', '90', '22', '23', '36', '19',
#        '17', '35', '26', '29', '25', '45', '40', '47', '56', '55', '42',
#        '49', '57', '37', '38', '58', '34', '50', '44', '39', '54', '51',
#        '52', '48', '43', '46', '53', '33', '41', '21', '27', '31', '24',
#        '-71', '-72', '-53', '-40', '-39', '-41', '28', '30', '-14', '-45',
#        '-56', '-73', '-75', '-12', '-22', '-44', '-42', '-43', '-74',
# ...

# %%
df['sla'].unique()
# Out:
# array([   5,    7,   10,    4,    6,    9,    8,    2,    3,   12,    1,
#          13,   11,   14,   19,   15,   17,   16,   20,   18,    0,   21,
#          25,   22,   41,   23,   39,   40,   33,  184,   38,   27,   35,
#          42,   28,   37,   26,   60,  175,  145,   56,   24,   29,   30,
#          31,   45,   44,   32, 1004, 1006,   34,   46,   61,   52,   51,
#          36,   43,   68,  239,   47])

# %% [markdown]
# # 서브 데이터 사전 EDA

# %%
df_media = pd.read_csv('Media Investment.csv')  # 광고 및 투자 내역
df_stock = pd.read_csv('NPS_Stockindex.csv')  # NPS(고객충성도 지표), Stock Index(주가 지수) 정보
df_promo = pd.read_csv('Special_Sale_Calendar.csv')  # 마케팅 프로모션 기간 정보

# %%
print(df_media.shape)
df_media.head(12)
# Out:
# (12, 12)
#     Year  Month  Total Investment   TV  Digital  Sponsorship  \
# 0   2015      7              17.1  0.2      2.5          7.4
# 1   2015      8               5.1  0.0      1.3          1.1
# 2   2015      9              96.3  3.9      1.4         62.8
# 3   2015     10             170.2  6.1     12.6         84.7
# 4   2015     11              51.2  4.2      1.3         14.2
# 5   2015     12             106.7  5.4      3.1         56.7
# 6   2016      1              74.2  4.4      0.5          4.2
# 7   2016      2              48.1  2.6      1.9         11.7
# 8   2016      3             100.0  9.3      2.1         41.6
# 9   2016      4              56.8  5.2      0.9         24.3
# 10  2016      5              78.1  1.4      0.8         31.7
# 11  2016      6              42.8  1.7      1.4         25.0
#
#     Content Marketing  Online marketing   Affiliates   SEM  Radio  Other
# 0                 0.0               1.3          0.5   5.0    0.0    0.0
# ...

# %%
print(df_stock.shape)
df_stock.head(10)
# Out:
# (2, 13)
#          index  July'15  Aug'15  Sept'15  Oct'15  Nov'15  Dec'15  Jan'16  \
# 0          NPS     54.6    60.0     46.9    44.4    47.0    45.8    47.1
# 1  Stock Index   1177.0  1206.0   1101.0  1210.0  1233.0  1038.0  1052.0
#
#    Feb'16  Mar'16  Apr'16  May'16  June'16
# 0    50.3    49.0    51.8    47.3     50.5
# 1  1222.0  1015.0  1242.0  1228.0   1194.0

# %%
print(df_promo.shape)
df_promo.head(10)
# Out:
# (6, 2)
#                          2015         2016
# 0              (18-19th July)  (20-22 Jan)
# 1               (15-17th Aug)    (1-2 Feb)
# 2               (28-30th Aug)  (20-21 Feb)
# 3               (15-17th Oct)  (14-15 Feb)
# 4                (7-14th Nov)    (7-9 Mar)
# 5  (25th Dec'15 - 3rd Jan'16)  (25-27 May)

# %%
print(df.isnull().sum())
print(df_media.isnull().sum())
print(df_stock.isnull().sum())
print(df_promo.isnull().sum())
# Out:
# fsn_id                             0
# order_date                         0
# Year                               0
# Month                              0
# order_id                           0
# order_item_id                      0
# gmv                                0
# units                              0
# deliverybdays                      0
# deliverycdays                      0
# s1_fact.order_payment_type         0
# sla                                0
# cust_id                            0
# pincode                            0
# product_analytic_super_category    0
# product_analytic_category          0
# product_analytic_sub_category      0
# product_analytic_vertical          0
# product_mrp                        0
# product_procurement_sla            0
# dtype: int64
# Year                 0
# Month                0
# Total Investment     0
# TV                   0
# Digital              0
# Sponsorship          0
# Content Marketing    0
# Online marketing     0
# ...
